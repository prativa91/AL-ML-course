# %%
print("a")
# Out:
# a

# %%
# write mode with buffering = -1
file = open("ab.txt",mode = "w", buffering = -1)
file.write("Hi\n")
file.close()

# %%
file = open("abc.txt",mode ="w",buffering = 1)
file.write("I am Learning Python\n")
file.write("Now i am learning file handling\n")
file.close()

# %%
file1 = open("abc.txt",mode ="w")
file1.write("I am Learning AI\n")
file1.close()

# %%
with open("abc.txt",mode = "w",buffering = -1) as f:
    f.write("I am Learning Python\n")
    f.write("Now i am learning file handling\n")

# %%
with open("abcd.txt", mode=  "a") as f:
    f.write("Hi I am Ram\n")

# %%
with open("abc.txt",mode = "w",buffering = -1) as f:
    content = ["Hi\n","Hello\n","How are you\n"]
    f.writelines(content)
    f.write("I am Learning Python\n")

# %%
with open("abc.txt",mode = "r") as f:
    # content = f.read()
    # content = f.readline()
    content = f.readlines()
    print(content)
    f.write("Hi")
# Out:
# ['Hi\n', 'Hello\n', 'How are you\n', 'I am Learning Python\n']
# ---------------------------------------------------------------------------
# UnsupportedOperation                      Traceback (most recent call last)
# /tmp/ipykernel_20127/3057946924.py in <module>
#       4     content = f.readlines()
#       5     print(content)
# ----> 6     f.write("Hi")
#
# UnsupportedOperation: not writable

# %%
with open("abc.txt",mode = "r+") as f:
    content = f.read()
    print(content)
    f.write("Hi2\n")
# Out:
# Hello world

# %%
with open("abc.txt",mode = "w+") as f:
    print(f.tell())
    f.write("Hello world")
    print(f.tell())
    f.seek(0)
    print(f.tell())
    content = f.read()
    print(content)
    print(f.tell())
# Out:
# 0
# 11
# 0
# Hello world
# 11

# %%
with open("abc.txt",mode=  "a+") as f:
    print(f.tell())
    f.write("There")
    print(f.tell())
    f.seek(0)
    print(f.read())
# Out:
# 46
# 51
# Hello worldThereThereThereThereThereThereThereThere

# %%
# csv file
# writee in csv file
content = [["Rama",12],["Saman",13]]
import csv
with open("student.csv",mode=  "w") as f:
    data = csv.writer(f)
    data.writerow(["Name","Rollno"])
    data.writerows(content)

# %%
with open("student.csv",mode=  "a") as f:
    data = csv.writer(f)
    data.writerow(["Deep",14])

# %%
with open("student.csv", mode=  "r") as f:
    data = csv.reader(f)
    for row in data:
        print(row)
# Out:
# ['Name', 'Rollno']
# ['Rama', '12']
# ['Saman', '13']
# ['Name', 'Rollno']
# ['Deep', '14']
# ['Deep', '14']
# ['Deep', '14']
