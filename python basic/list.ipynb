# %%
my_list =[1,2,3,4,5]

# %%
my_list[0]
# Out:
# 1

# %%
my_list[1] = 10#modify
my_list
# Out:
# [1, 10, 3, 4, 5, 4, 4]

# %%
my_list.append(4)
my_list
# Out:
# [1, 10, 3, 4, 5, 4, 4]

# %%
my_list.extend([6,7])
my_list
# Out:
# [1, 10, 3, 4, 5, 4, 4, 6, 7]

# %%
my_list.remove(10)
my_list
# Out:
# [1, 3, 4, 5, 4, 4, 6, 7]

# %%
my_list.pop(2)
my_list
# Out:
# [1, 3, 5, 4, 4, 6, 7]

# %%
my_list.clear()
my_list
# Out:
# []

# %%
my_list =[1,2,3,4,5]
# Out:
# [1, 2, 3, 4, 5]

# %%
my_list.index(3)
my_list
# Out:
# [1, 2, 3, 4, 5]

# %% [markdown]
# Membership test

# %%
3 in my_list
# Out:
# True

# %%
my_list[1:4]
# Out:
# [2, 3, 4]

# %%
len(my_list)
# Out:
# 5
