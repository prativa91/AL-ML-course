# %% [markdown]
# hign ->low ma jada compile time
# exceution ->runtime

# %% [markdown]
# EXCEPTION=RUNTIME ERROR

# %% [markdown]
# TRY:
#            risky_code         ->      [in future if error occur]
# EXCEPT:
#           handle_error        ->      [catch error]
# FINALLY:
#            final statement     ->     [j vayani execute hunxa]

# %%
l=[1,2,3,4]
print(l[6])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[1], line 2
#       1 l=[1,2,3,4]
# ----> 2 print(l[6])
#
# IndexError: list index out of range

# %%
d={"a":1,"b":2}
print(d["c"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[2], line 2
#       1 d={"a":1,"b":2}
# ----> 2 print(d["c"])
#
# KeyError: 'c'

# %%
a=5
print(b)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 2
#       1 a=5
# ----> 2 print(b)
#
# NameError: name 'b' is not defined

# %%
a=int(input("enter num"))
a
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 a=int(input("enter num"))
#       2 a
#
# ValueError: invalid literal for int() with base 10: 'd'

# %%
a="int"+5
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 a="int"+5
#
# TypeError: can only concatenate str (not "int") to str

# %%
try:
    l=[1,2,3,4.5]
    print(l[6])
except Exception as e:
    print(type(e),__name__)
    print(e)
finally:
    print("finally executed")
# Out:
# <class 'IndexError'> __main__
# list index out of range
# finally executed

# %%
try:
    d={"a":1,"b":2}
    print(d["c"])
except Exception as e:
    print(type(e),__name__)
    print(e)
finally:
    print("finally executed")
# Out:
# <class 'KeyError'> __main__
# 'c'
# finally executed

# %%
try:
    a=int(input("enter num"))
    print(a)
except ValueError as e:
    print(type(e),__name__)
    print(e)
finally:
    print("finally executed")
# Out:
# <class 'ValueError'> __main__
# invalid literal for int() with base 10: 'g'
# finally executed

# %%
try:
    a="int"+5
    print(a)
except TypeError as e:
    print(type(e),__name__)
    print(e)
finally:
    print("finally executed")
# Out:
# <class 'TypeError'> __main__
# can only concatenate str (not "int") to str
# finally executed

# %% [markdown]
# 1. Write a function named calculate_area(length, width)
# that calculates and returns the area of a rectangle.
# Requirements:
# 1. Accept length and width as parameters;
# 2. Return the area;
# 3. Call the function and display the returned value.
