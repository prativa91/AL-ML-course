# %% [markdown]
# COMPOSITION #########self
#
#
# self order vitra use gryako vayara self use vakoho
# order-parent class

# %%
class Customer:
    def __init__(self,name,location):
        self.name=name
        self.location=location

    def c_info(self):
        return f"{        self.name}from {        self.location}"
class Product:
    def __init__(self,item,price):
        self.item=item
        self.price=price

    def p_info(self):
        return f"{        self.item} item price is  {        self.price}"

class Order:
    def __init__(self,name,location,item,price,orderid):
        self.orderid=orderid
        self.c1=Customer(name,location)
        self.p1=Product(item,price)##################################
        
    def display_info(self):
        print(self.c1.c_info())
        print(self.p1.p_info())



        return f" orderid is {self.orderid}"

# %%
o=Order("PRA","KTM","CLOTHES",350,12)
o.display_info()
# Out:
# PRAfrom KTM
# CLOTHES item price is  350
# ' orderid is 12'

# %% [markdown]
# AGGREGATION########argument jastari pass garinxa

# %%
class Employee:
    def __init__(self,name,emp_id):
        self.name=name
        self.id=emp_id
    def e_info(self):
        return f"employee name :{self.name} with id{self.id}"

class Department:
    def __init__(self,dname,obj_e1):
        self.dname=dname
        self.obj_e1=obj_e1
    def d_info(self):
        print(self.obj_e1.e_info())
        return f"Department name is :{self.dname} "

# %%
e1=Employee("pra",1234)
d1=Department("IT",e1)

# %%
d1.d_info()
# Out:
# employee name :pra with id1234
# 'Department name is :IT '

# %% [markdown]
# ABSTRACT CLASS METHOD

# %%
from abc import ABC ,abstractmethod
class Payment(ABC):
    @abstractmethod
    def payment(self):
        pass

class Esewa(Payment):
    def payment(self):#must be run
        return "payment made through esewa"
    def pay(self):
        return "Payment done "
class khalti(Payment):
    def payment(self):#must be run
        return "payment made through khalti"

# %%
e1=Esewa()
e1.payment()
# Out:
# 'payment made through esewa'

# %%
e1.pay()
# Out:
# 'Payment done '

# %% [markdown]
# ACCESS MODIFLER
#
# ################################################################
# NAME MANAGLING ######### hrne k haexa
#
# ########################################
# PROTECTED MEMBER
# ->>>>>>>>>>USE OF SINGLE UNDERSCORE(_) SELF._NAME  ->>>>FUNCTION AGHI PANI _ HUNU PRXA def _vnn()
# PRIVATE MEMBER
# ->>>>>>>>>>>> USE OF DOUBLE UNDERSCORE(__) SELF.__NAME ->>>>FUNCTION AGHI PANI __ HUNU PRXA def __vnn()
